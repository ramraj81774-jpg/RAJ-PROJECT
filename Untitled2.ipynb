# %% [markdown]
# <a href="https://colab.research.google.com/github/ramraj81774-jpg/RAJ-PROJECT/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd
from io import StringIO

# Dummy data to allow the notebook to run. Please replace with your actual 'sales.csv' data.
csv_data = """customer_id,signup_date,country,gender,loyalty_tier,acquisition_channel,age
1,08-04-2021,BR,Male,Bronze,Referral,30
2,28-04-2023,IN,Female,Silver,Organic,45
3,18-12-2022,UK,Female,Silver,Organic,22
4,26-04-2022,US,Male,Silver,Paid Search,50
5,20-04-2022,IN,Male,Silver,Organic,38
6,01-01-2022,CA,Female,Gold,Referral,28
7,15-03-2023,AU,Male,Platinum,Organic,60
"""

df = pd.read_csv(StringIO(csv_data))

# %%
print(df.head())
# Out:
#    customer_id signup_date country  gender loyalty_tier acquisition_channel  \
# 0            1  08-04-2021      BR    Male       Bronze            Referral
# 1            2  28-04-2023      IN  Female       Silver             Organic
# 2            3  18-12-2022      UK  Female       Silver             Organic
# 3            4  26-04-2022      US    Male       Silver         Paid Search
# 4            5  20-04-2022      IN    Male       Silver             Organic
#
#    age
# 0   30
# 1   45
# 2   22
# 3   50
# 4   38

# %%
encoder=LabelEncoder()
df['loyalty_tier']=encoder.fit_transform(df['loyalty_tier'])

# %%
print(df[['loyalty_tier']].head())
# Out:
#    loyalty_tier
# 0             0
# 1             3
# 2             3
# 3             3
# 4             3

# %%
x=df[['age','loyalty_tier']]

# %%
model=KMeans(n_clusters=3,
             random_state=42,
             n_init='auto')
model.fit(x)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
df['cluster']=model.labels_
print("Clustered customers")
# Out:
# Clustered customers

# %%
print(model.cluster_centers_)
# Out:
# [[26.66666667  1.33333333]
#  [60.          2.        ]
#  [44.33333333  3.        ]]

# %%
plt.figure(figsize=(8,5))
plt.scatter(
    df['age'],
    df['loyalty_tier'],
c=df['cluster'],
    cmap='rainbow'
)

# %%
plt.scatter(
    model.cluster_centers_[:,0],
    model.cluster_centers_[:,1],
    s=200,
    marker='X'
)

# %%
plt.xlabel("Age")
plt.ylabel("Loyalty Tier")
plt.title("Customer Segmentation")
plt.yticks(
    [0, 1, 2, 3], # Assuming LabelEncoder maps Bronze:0, Gold:1, Platinum:2, Silver:3 alphabetically
    ['Bronze', 'Gold', 'Platinum', 'Silver']
)
plt.show()
